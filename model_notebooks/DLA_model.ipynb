# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random

# %%
def DLA():
    size = 128
    loop = 50
    stepLoop = min(1000, loop)
    limit = 100000

    loopNumber = int(loop / stepLoop)
    result_box = np.zeros(shape=(loopNumber, size * size))

    h = np.zeros((size, size))
    m = int(size / 2)
    r = m
    r_init = 30

    # Initial condition
    h[m, m] = 1

    # Initial start radius
    r = r_init
    flag = False

    result_list = []
    for t in range(loopNumber):
        for i in range(stepLoop):
            # Set up to retry if the initial position falls within the cluster once it has grown sufficiently large
            start_point = 1
            while start_point == 1:
                if r > size //

# %%
result_list = DLA()
